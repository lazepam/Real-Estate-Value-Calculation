# %% [markdown]
# # Estimation Of Sale Price Of Properties in MIT Town
#
# ## Ahmet DERYA

# %% [markdown]
# # Index
#
# - [Abstract](#Abstract)
# - [1. Introduction](#1.-Introduction)
# - [2. The Data](#2.-The-Data)
#     - [2.1 Import the Data](#2.1-Import-the-Data)
#     - [2.2 Data Exploration](#2.2-Data-Exploration)
#     - [2.3 Data Preparation](#2.3-Data-Preparation)
#     - [2.4 Correlation](#2.4-Correlation)
# - [3. Project Description](#3.-Project-Description)
#     - [3.1 Linear Regression](#3.1-Linear-Regression)
#     - [3.2 Analysis](#3.2-Analysis)
#     - [3.3 Results](#3.3-Results)
#     - [3.4 Verify Your Model Against Test Data](#3.4-Verify-Your-Model-Against-Test-Data)
# - [Conclusion](#Conclusion)
# - [References](#References)

# %% [markdown]
# [Back to top](#Index)
#
#
# ##  Abstract
#
#     In this study, a linear regression model was created to estimate the sales prices of properties in MIT Town a independent data in the linear regression analysis. In this regression analysis, attributes that can obtain numeric data and have sufficient data were selected.
#     As a result of the data analysis Total number of rooms above ground (excluding bathrooms), Full above ground bathrooms, Wall covering area in square meters, Rate t he general material and finish of the house, Original construction date, Above ground (floor) living area sq uare feet data are determined as independent variables in order to calculate dependent values that SalePrice.

# %% [markdown]
# [Back to top](#Index)
#
#
# ## 1. Introduction
#
#        While preparing this Project, the data in the House Data database were used. The Sale Prices of the properties in the House Data database were determined according to the given eighty-two features.
#
#        In addition to the numerical values suitable for linear regression calculation, a total of forty-five of the values that can be converted into numerical values were included in the pre-evaluation in order to estimate the Sale Price.
#
#        Features that do not contain data or that do not contain sufficient data or that may prevent a more accurate analysis at the next stage were not evaluated. Correlations were observed between the remaining data and sales prices.
#
#        As a result of the observations, it has been determined that some features affect the sales price more than others.
#
#        Q. From these data, GarageArea: Size of the garage in square feet, TotRmsAbGrd: Total above-floor room (excluding bathrooms), FullBath: Above-floor full bathrooms, MasnrArea: Wall covering area in square feet, OverallQual: Overall proportions house material and finish , Year of construction: Original construction date, GrLivA rea: Above ground living space square feet.
#
#        Missing data was detected on these data and data cleaning was performed.
#
#        After the necessary arrangements of these independent data were made, coding and formulations were made.
#
#        It has been determined that the data will be more suitable for linear regression analysis to be used in sales price estimation.
#
#        As a result of the analyzes made with these independent data used, a positive correlation of 0.79 was found between the data and the selling price.

# %% [markdown]
# [Back to top](#Index)
#
# ## 2. The Data
#
#     All data used for this project were obtained from the House Data database as previously given.
#
#     It was determined that this data was in the Pandas DataFrame structure and which data type the data was in.
#
#     Detected which data is float64 or convertable to numeric data.
#
#     With it, the values of the data of the study file such as mean, max, min, standard deviation were observed.

# %% [markdown]
# [Back to top](#Index)
#
# ### 2.1 Import the Data
#
#        The necessary Python libraries and data were imported to prepare the project.
#
#         A general view of the imported data was observed.
#
#         Mathematical data of these data such as min, max, mean, standard deviation were examined.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/houseSmallData.csv',index_col=0)

# %%
data.shape
# Out:
# (100, 81)

# %%
data.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             100 non-null    int64
#  1   MSSubClass     100 non-null    int64
#  2   MSZoning       100 non-null    object
#  3   LotFrontage    86 non-null     float64
#  4   LotArea        100 non-null    int64
#  5   Street         100 non-null    object
#  6   Alley          6 non-null      object
#  7   LotShape       100 non-null    object
#  8   LandContour    100 non-null    object
#  9   Utilities      100 non-null    object
#  10  LotConfig      100 non-null    object
#  11  LandSlope      100 non-null    object
#  12  Neighborhood   100 non-null    object
#  13  Condition1     100 non-null    object
#  14  Condition2     100 non-null    object
#  15  BldgType       100 non-null    object
#  16  HouseStyle     100 non-null    object
# ...

# %%
saleprice = data['SalePrice']
saleprice.describe()
# Out:
# count       100.000000
# mean     173820.660000
# std       72236.552886
# min       40000.000000
# 25%      129362.500000
# 50%      153750.000000
# 75%      207750.000000
# max      438780.000000
# Name: SalePrice, dtype: float64

# %%
data.describe()
# Out:
#                Id  MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  100.000000  100.000000    86.000000    100.000000   100.000000
# mean    50.500000   52.000000    71.406977  10115.870000     5.980000
# std     29.011492   42.545282    21.093840   5130.541763     1.530696
# min      1.000000   20.000000    21.000000   1596.000000     3.000000
# 25%     25.750000   20.000000    60.000000   7643.250000     5.000000
# 50%     50.500000   45.000000    70.000000   9595.500000     6.000000
# 75%     75.250000   60.000000    84.000000  11243.250000     7.000000
# max    100.000000  190.000000   122.000000  50271.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count    100.00000   100.000000    100.000000   100.000000   100.000000  ...
# mean       5.50000  1971.410000   1983.920000   121.640000   454.560000  ...
# std        0.97959    29.373284     20.967353   213.553982   462.034922  ...
# ...

# %% [markdown]
# [Back to top](#Index)
#
# ### 2.2 Data Exploration
#
#     After the data were obtained, numeric features (colums) suitable for use in linear regression were selected from among them.
#
#     The correlation relations between these features and sales prices were examined, respectively. The data obtained were sorted in order of relationship from high to low.
#
#     In this study, the saleprice colon was examined first in order to obtain more statistical information about this column, since the sale price is a dependent variable. It was checked whether it showed a normal distrib ution. The strength of this normal distribution was examined by taking its logarithm.
#
#     The plot graph of the SalePrice data was analyzed before looking at the scatter chart between each column an d SalePrice.
#
#     It was observed that there was not quite complete normal distribution.
#
#     Correlation relations between the numerical ones among the 82 data in the file and the sale price were obser ved to be potentially used in the formulation later on.
#
#     The index information of the data with a high correlation relationship is displayed to be used in the formul ation to be created later.
#
#     The graphs of the values showing the highest correlation relationship were prepared one by one.
#
#     SalePrice parameter set to Y colon. Then enter all parameters in order (GarageArea, TotRmsGrd, FilBath, Mas VnrArea, OverallQual, YearBuilt, GrLivArea)
#
#     Scatter plot graphs were drawn by giving the X value and the relationship between them was graphically observed.

# %%
data['HouseStyle'].unique()
# Out:
# array(['2Story', '1Story', '1.5Fin', '1.5Unf', 'SFoyer', 'SLvl', '2.5Unf'],
#       dtype=object)

# %%
df_houseStyle = pd.get_dummies(data['HouseStyle'],drop_first=True)
df_houseStyle.head(5)
# Out:
#    1.5Unf  1Story  2.5Unf  2Story  SFoyer  SLvl
# 0       0       0       0       1       0     0
# 1       0       1       0       0       0     0
# 2       0       0       0       1       0     0
# 3       0       0       0       1       0     0
# 4       0       0       0       1       0     0

# %%
data["HouseStyle"].head(5)
# Out:
# 0    2Story
# 1    1Story
# 2    2Story
# 3    2Story
# 4    2Story
# Name: HouseStyle, dtype: object

# %%
data_merged = data.merge(df_houseStyle, left_index=True, right_index=True)

# %%
data_merged
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ...         ...      ...          ...      ...    ...   ...      ...
# 95   96          60       RL          NaN     9765   Pave   NaN      IR2
# 96   97          20       RL         78.0    10264   Pave   NaN      IR1
# 97   98          20       RL         73.0    10921   Pave   NaN      Reg
# 98   99          30       RL         85.0    10625   Pave   NaN      Reg
# 99  100          20       RL         77.0     9320   Pave   NaN      IR1
#
#    LandContour Utilities  ... YrSold SaleType SaleCondition SalePrice 1.5Unf  \
# ...

# %%
numericdata = data.select_dtypes(include=[np.number])
numericdata
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1          60         65.0     8450            7            5
# 1     2          20         80.0     9600            6            8
# 2     3          60         68.0    11250            7            5
# 3     4          70         60.0     9550            7            5
# 4     5          60         84.0    14260            8            5
# ..  ...         ...          ...      ...          ...          ...
# 95   96          60          NaN     9765            6            8
# 96   97          20         78.0    10264            7            5
# 97   98          20         73.0    10921            4            5
# 98   99          30         85.0    10625            5            5
# 99  100          20         77.0     9320            4            5
#
#     YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  OpenPorchSF  \
# 0        2003          2003       196.0         706  ...           61
# ...

# %%
data['SalePrice']
# Out:
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#        ...
# 95    185000
# 96    214000
# 97     94750
# 98     83000
# 99    128950
# Name: SalePrice, Length: 100, dtype: int64

# %% [markdown]
# [Back to top](#Index)
#
# ### 2.3 Data Preparation
#
#     Before starting the analysis, data showing a high correlation (over 0.5) relationship with the sales price d ata were determined. The index information of these data was obtained. The necessary graphs of each one with the price of saris were examined.
#
#     Despite these, in order to see whether these data are suitable for use in the formulation to be applied, it was checked whether there were missing data in the contents of these columns.
#
#     Columns with too many null values were not included in the evaluation because they would adversely affect t he prediction calculation.
#
#     However, columns with a small number of null values were included in the evaluation because they may affect the prediction value relatively less negatively.
#
#     The null values of these columns with a small number of null values were filled with the average value of th e column in which they were included
#
#     However, due to the nature of NaN, an infinite or very large value data frame type, missing data in another type, series format, has been updated.
#
#     The sales price column of the dependent variable was assigned as the Y variable. Therefore, the Sales price column was removed from the independent variables.

# %%
plt.hist(data['SalePrice'])
# Out:
# (array([ 2., 17., 35., 17., 11.,  8.,  5.,  3.,  1.,  1.]),
#  array([ 40000.,  79878., 119756., 159634., 199512., 239390., 279268.,
#         319146., 359024., 398902., 438780.]),
#  <BarContainer object of 10 artists>)

# %%
np.log(data.SalePrice).hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(np.log(saleprice))
np.log(saleprice).skew()
# Out:
# -0.09632240207755555

# %%
Y = data['SalePrice']
G = data['GrLivArea']
plt.scatter(G , Y)

# %%
GA = data['GarageArea']
plt.scatter(GA, Y)

# %% [markdown]
# [Back to top](#Index)
#
# ### 2.4 Correlation
#
#     The proportional relations with the obtained past dominance were observed. As a result of this observation, 'OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars' objects that show the strongest border relationship with SalePrice were extracted from the others to be used in the Sale Price estimation to be created.

# %%
numeric = data.select_dtypes(include=[np.number])
numeric.shape
# Out:
# (100, 39)

# %%
corr = numeric.corr()
corr['SalePrice']
# Out:
# Id              -0.162735
# MSSubClass      -0.066819
# LotFrontage      0.302526
# LotArea          0.497124
# OverallQual      0.855061
# OverallCond     -0.170443
# YearBuilt        0.658636
# YearRemodAdd     0.548330
# MasVnrArea       0.571836
# BsmtFinSF1       0.266713
# BsmtFinSF2      -0.138126
# BsmtUnfSF        0.327020
# TotalBsmtSF      0.616297
# 1stFlrSF         0.550912
# 2ndFlrSF         0.381076
# LowQualFinSF    -0.150027
# GrLivArea        0.735129
# BsmtFullBath     0.155689
# BsmtHalfBath    -0.055100
# FullBath         0.579505
# HalfBath         0.319304
# BedroomAbvGr     0.233426
# KitchenAbvGr    -0.235659
# TotRmsAbvGrd     0.553603
# Fireplaces       0.487907
# GarageYrBlt      0.603635
# GarageCars       0.663441
# GarageArea       0.688249
# WoodDeckSF       0.451241
# OpenPorchSF      0.301960
# EnclosedPorch   -0.233483
# 3SsnPorch       -0.019391
# ScreenPorch      0.035930
# PoolArea              NaN
# PoolQC                NaN
# ...

# %%
cols = corr['SalePrice'].sort_values(ascending=False)[0:5]
cols
# Out:
# SalePrice      1.000000
# OverallQual    0.855061
# GrLivArea      0.735129
# GarageArea     0.688249
# GarageCars     0.663441
# Name: SalePrice, dtype: float64

# %%
cols = corr['SalePrice'].sort_values(ascending=False)[0:5].index
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageArea', 'GarageCars'], dtype='object')

# %%
datagroup = data.iloc[0:20,:]
datagroup.shape
# Out:
# (20, 81)

# %%
X = datagroup[cols]
X
# Out:
#     SalePrice  OverallQual  GrLivArea  GarageArea  GarageCars
# 0      208500            7       1710         548           2
# 1      181500            6       1262         460           2
# 2      223500            7       1786         608           2
# 3      140000            7       1717         642           3
# 4      250000            8       2198         836           3
# 5      143000            5       1362         480           2
# 6      307000            8       1694         636           2
# 7      200000            7       2090         484           2
# 8      129900            7       1774         468           2
# 9      118000            5       1077         205           1
# 10     129500            5       1040         384           1
# 11     345000            9       2324         736           3
# 12     144000            5        912         352           1
# 13     279500            7       1494         840           3
# ...

# %%
nulls = pd.DataFrame(datagroup.isnull().sum().sort_values(ascending=False))
nulls
# Out:
#               0
# Alley        20
# PoolQC       20
# MiscFeature  16
# Fence        16
# FireplaceQu   8
# ...          ..
# MasVnrArea    0
# MasVnrType    0
# Exterior2nd   0
# Exterior1st   0
# SalePrice     0
#
# [81 rows x 1 columns]

# %%
nulls = pd.DataFrame(datagroup.isnull().sum().sort_values(ascending=True))
nulls
# Out:
#                0
# Id             0
# TotRmsAbvGrd   0
# KitchenQual    0
# KitchenAbvGr   0
# BedroomAbvGr   0
# ...           ..
# FireplaceQu    8
# Fence         16
# MiscFeature   16
# Alley         20
# PoolQC        20
#
# [81 rows x 1 columns]

# %%
plt.scatter(data['OverallQual'], data['SalePrice'])

# %%
plt.scatter(data['GrLivArea'], data['SalePrice'])

# %%
plt.scatter(data['GarageArea'], data['SalePrice'])

# %% [markdown]
# [Back to top](#Index)
#
# ## 3. Project Description
#
# Describe, using 150 words or less, how your analysis improves upon the analysis performed by Dr. Williams. Explain the variables that you analyzed, why you selected them, and what relationships you determined in your analysis.
# Make sure you explain specifically what findings you derived from your analysis of the data.

# %% [markdown]
# [Back to top](#Index)
#
# ### 3.1 Linear Regression
#   SIMPLE LINEAR CORRELATION;
#
#     Simple linear correlation is a measure of the degree to which two variables vary together, or a measure of the intensity of the association between two variables.
#
#     Correlation often is abused. You need to show that one variable actually is affecting another variable.
#
#     The parameter being measure is D (rho) and is estimated by the statistic r, the correlation coefficient.
#
#     r can range from -1 to 1, and is independent of units of measurement.
#
#     The strength of the association increases as r approaches the absolute value of 1.0
#
#     A value of 0 indicates there is no association between the two variables tested.

# %% [markdown]
# [Back to top](#Index)
#
# ### 3.2 Analysis
#
#     As a result of all coding and calculations, the correlation relationship between SalePrice and OverallQual, GrLivArea, GarageArea, GarageCars was calculated as positive 0.79.
#
#     In order to increase this correlation relationship, other features of the data obtained from House Data can be added. However, it may cause inaccurate calculations due to the lack of data.

# %%
X = data[cols]
Y = data['SalePrice']
X = X.drop(['SalePrice'], axis = 1)

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X, Y)
predictions = model.predict(X)
X
# Out:
#     OverallQual  GrLivArea  GarageArea  GarageCars
# 0             7       1710         548           2
# 1             6       1262         460           2
# 2             7       1786         608           2
# 3             7       1717         642           3
# 4             8       2198         836           3
# ..          ...        ...         ...         ...
# 95            6       1470         420           2
# 96            7       1588         472           2
# 97            4        960         432           1
# 98            5        835         366           1
# 99            4       1225           0           0
#
# [100 rows x 4 columns]

# %%
model.score(X, Y)
# Out:
# 0.7916699059969976

# %%
X = data[["GrLivArea", "GarageArea","OverallQual"]]
Y = data.SalePrice

lr = linear_model.LinearRegression()
model = lr.fit(X, Y)
print(model.intercept_)
print(model.coef_)
# Out:
# -71921.07185046785
# [   44.3738574     55.61914047 26000.67863285]

# %% [markdown]
# [Back to top](#Index)
#
# ### 3.3 Results
#
# The result of the correlasyon analysis for the prepared model was found to be 0.9495158148743928.
#
# The data preparations for this model are given above.
#
# The codings made are listed below along with the result.

# %% [markdown]
# [Back to top](#Index)
#
# ### 3.4 Verify Your Model Against Test Data
#
#     A close relationship was observed when the data were compared with the test data.

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X, Y)
predictions = model.predict(X)
print(f"R^2 is: {model.score(X, Y)}")
# Out:
# R^2 is: 0.789158151143107

# %%
plt.scatter(predictions,Y)

# %%
plt.hist(Y - predictions)
# Out:
# (array([ 5.,  3.,  5., 13., 29., 24.,  8.,  8.,  3.,  2.]),
#  array([-84932.65934685, -67293.91268757, -49655.16602829, -32016.41936901,
#         -14377.67270974,   3261.07394954,  20899.82060882,  38538.5672681 ,
#          56177.31392737,  73816.06058665,  91454.80724593]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(predictions,Y,color='red')

# %% [markdown]
# [Back to top](#Index)
#
# ## Conclusion
#
#     With the Linear regression analysis, a prediction about the dependent data was obtained as a result of calcu lating the independent data in our city with an appropriate formula.
#
#     The closeness of this prediction to the real values was evaluated by the correlation coefficient being 1 or close to -1 in an inverse relationship.
#
#     With the finding of this number as 0.79 in the module we made, it was concluded that the prediction we wil l make about the dependent value will be close to the real SalePrice value.

# %% [markdown]
# [Back to top](#Index
# )
# ## References
#
# Use this format for websites:
#
#
# • Nort Dacota State University, 2023.https://www.ndsu.edu/faculty/horsley/corr.pdf.
